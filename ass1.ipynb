# %%
import pandas as pd

# %%
df=pd.read_csv("credit_card_fraud_synthetic.csv")

# %%
df
# Out:
#        Time        V1        V2        V3        V4        V5   Amount  Class
# 0    121958 -2.289061 -1.313758 -0.452562 -0.392802  0.224787  1600.89      0
# 1    146867  1.432482 -1.095302 -0.129910 -1.362911 -1.017335  4191.85      0
# 2    131932  1.214722 -0.168797  0.581433  0.699020  0.964415  3271.32      0
# 3    103694 -0.880864  0.110956 -0.203236 -0.243510  0.362543  1377.51      0
# 4    119879 -0.881879  0.786970  1.110118  0.015365 -1.135162  4838.72      0
# ..      ...       ...       ...       ...       ...       ...      ...    ...
# 995  150168 -0.239297 -0.093612  0.674449 -1.934307  0.201932  1863.34      0
# 996   67728 -0.717823  0.704535  0.347665  0.158832 -0.295808  1152.10      0
# 997  165088 -0.484361  1.489765 -0.921505 -0.624253  1.588061  2805.25      0
# 998   11246  1.053057 -0.885100 -0.391480  0.000222 -0.077757   672.88      0
# 999  149453  2.033305  1.457079 -0.159335  1.651450 -0.186564  1601.27      0
#
# [1000 rows x 8 columns]

# %%
df.head()
# Out:
#      Time        V1        V2        V3        V4        V5   Amount  Class
# 0  121958 -2.289061 -1.313758 -0.452562 -0.392802  0.224787  1600.89      0
# 1  146867  1.432482 -1.095302 -0.129910 -1.362911 -1.017335  4191.85      0
# 2  131932  1.214722 -0.168797  0.581433  0.699020  0.964415  3271.32      0
# 3  103694 -0.880864  0.110956 -0.203236 -0.243510  0.362543  1377.51      0
# 4  119879 -0.881879  0.786970  1.110118  0.015365 -1.135162  4838.72      0

# %%
df.tail()
# Out:
#        Time        V1        V2        V3        V4        V5   Amount  Class
# 995  150168 -0.239297 -0.093612  0.674449 -1.934307  0.201932  1863.34      0
# 996   67728 -0.717823  0.704535  0.347665  0.158832 -0.295808  1152.10      0
# 997  165088 -0.484361  1.489765 -0.921505 -0.624253  1.588061  2805.25      0
# 998   11246  1.053057 -0.885100 -0.391480  0.000222 -0.077757   672.88      0
# 999  149453  2.033305  1.457079 -0.159335  1.651450 -0.186564  1601.27      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    1000 non-null   int64
#  1   V1      1000 non-null   float64
#  2   V2      1000 non-null   float64
#  3   V3      1000 non-null   float64
#  4   V4      1000 non-null   float64
#  5   V5      1000 non-null   float64
#  6   Amount  1000 non-null   float64
#  7   Class   1000 non-null   int64
# dtypes: float64(6), int64(2)
# memory usage: 62.6 KB

# %%
df.corr()
# Out:
#             Time        V1        V2        V3        V4        V5    Amount  \
# Time    1.000000  0.003712 -0.014759 -0.025795  0.069737 -0.058153  0.054233
# V1      0.003712  1.000000  0.007395  0.002214 -0.030697  0.088616  0.032516
# V2     -0.014759  0.007395  1.000000  0.061603 -0.016288 -0.035025 -0.026302
# V3     -0.025795  0.002214  0.061603  1.000000  0.021182  0.035898  0.056290
# V4      0.069737 -0.030697 -0.016288  0.021182  1.000000 -0.019725 -0.024785
# V5     -0.058153  0.088616 -0.035025  0.035898 -0.019725  1.000000  0.013353
# Amount  0.054233  0.032516 -0.026302  0.056290 -0.024785  0.013353  1.000000
# Class  -0.011274  0.018705 -0.015838 -0.022576  0.026938  0.001215 -0.018301
#
#            Class
# Time   -0.011274
# V1      0.018705
# V2     -0.015838
# V3     -0.022576
# V4      0.026938
# V5      0.001215
# Amount -0.018301
# Class   1.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['V1'],df['Class'])

# %%
plt.scatter(df['V2'],df['Class'])

# %%
plt.scatter(df['V3'],df['Class'])

# %%
plt.scatter(df['V4'],df['Class'])

# %%
plt.scatter(df['V5'],df['Class'])

# %%
plt.scatter(df['V1'],df['Amount'])

# %%
plt.scatter(df['V2'],df['Amount'])

# %%
plt.scatter(df['V3'],df['Amount'])

# %%
plt.scatter(df['V4'],df['Amount'])

# %%
plt.scatter(df['V5'],df['Amount'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    1000 non-null   int64
#  1   V1      1000 non-null   float64
#  2   V2      1000 non-null   float64
#  3   V3      1000 non-null   float64
#  4   V4      1000 non-null   float64
#  5   V5      1000 non-null   float64
#  6   Amount  1000 non-null   float64
#  7   Class   1000 non-null   int64
# dtypes: float64(6), int64(2)
# memory usage: 62.6 KB

# %%
from sklearn.linear_model import LinearRegression

# %%
x=df[['V1']]
y=df['Class']

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[20]])
# Out:
# c:\Documents\machineLearning\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.06588324])

# %%
slope=model.coef_

# %%
slope
# Out:
# array([0.00239627])

# %%
intercept=model.intercept_

# %%
intercept
# Out:
# np.float64(0.017957802068988952)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,y_test,y_train,x_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
x_train
# Out:
#            V1
# 29   1.567594
# 535  0.292994
# 695  0.161440
# 557  0.943464
# 836  0.010023
# ..        ...
# 106 -0.770522
# 270  0.243496
# 860  2.363633
# 435  1.498565
# 102  0.063633
#
# [800 rows x 1 columns]

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=model.predict(x_train)

# %%
y_train-ypred
# Out:
# 29    -0.022113
# 535   -0.018316
# 695   -0.017925
# 557   -0.020254
# 836   -0.017473
#          ...
# 106   -0.015148
# 270   -0.018169
# 860   -0.024485
# 435   -0.021908
# 102   -0.017633
# Name: Class, Length: 800, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score

# %%
y_pred=model.predict(x_train)
r2_score=r2_score(y_train, y_pred)

# %%
r2_score
# Out:
# 0.0005520609760832906

# %%
MAE=mean_absolute_error(y_train, y_pred)

# %%
MAE
# Out:
# 0.03436851600318493

# %%
MSE=mean_squared_error(y_train,y_pred)

# %%
MSE
# Out:
# 0.017184258001592467

# %%
RMSE=root_mean_squared_error(y_train, y_pred)

# %%
RMSE
# Out:
# 0.1310887409413656
