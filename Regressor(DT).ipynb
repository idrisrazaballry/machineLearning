# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import seaborn as sns

# %%
df = pd.read_csv("laptop.csv")

# %%
print(df.head())

# %%
X = df.drop('Price', axis=1)   # Replace 'Price' with your target column name
y = df['Price']

# %%
X.corr(numeric_only=True)

# %%
num_col =  X.select_dtypes(include='number').columns # selecting only numeric cols from dataframe
obj_col = X.select_dtypes(include='object').columns
print(num_col)
print(obj_col)

# %%
model = DecisionTreeRegressor()

# %%
sns.boxplot(X[num_col])

# %%
X[obj_col].nunique() # To find number of unique values

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,random_state=42,train_size=0.8)

# %%
print(X.dtypes)

# %%
import category_encoders as ce
obj_col

encoder = ce.OrdinalEncoder(cols=obj_col)

xtrain = encoder.fit_transform(xtrain)
xtest = encoder.transform(xtest)

# %%
model.fit(xtrain,ytrain)

# %%
print(df.head())
print(df.dtypes)

# %%
print(df.columns)

# %%
y_pred = model.predict(xtest)

# %%
y_pred = model.predict(xtest)

print("MAE:", mean_absolute_error(ytest, y_pred))
print("MSE:", mean_squared_error(ytest, y_pred))
print("R² Score:", r2_score(ytest, y_pred))

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(18, 10))

plot_tree(
    model,
    feature_names=xtrain.columns,
    #class_names=model.classes_,
    filled=True,
    rounded=True,
    fontsize=10
)

plt.show()
